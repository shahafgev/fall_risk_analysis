# %% [markdown]
# # Evaluate and determine the zed crossing point +
# # Compute measurements.csv for both groups

# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
from src.preprocessing import show_decision_trim_plots, process_all_experiments, get_total_time_per_trial

# %% [markdown]
# # Older Adults

# %% [markdown]
# Participants:
# 1. ann         11. ester      21. mordehai    31. tina
# 2. anna        12. fabian     22. moshe       32. tova
# 3. ann-m       13. gidon      23. naftali     33. uri
# 4. arie        14. gita       24. naomi       34. yaacov
# 5. avraham     15. ilana      25. rahel       35. yaacov_e
# 6. bat-sheva   16. inez       26. raya        36. yaffa
# 7. batya       17. mazal      27. ronald      37. yossef
# 8. benny       18. meir       28. shalom      38. yossi
# 9. david       19. michael    29. shalom_l
# 10. dida       20. miryam     30. tami

# %%
participant_name = 'ann'

# %%
eyes_open = [50, 50, 50, 50, 150]

# %%
for index in range(1, 6):
    print(f"Index: {index}")
    # Build the full path to the CSV, relative to notebook
    csv_path = os.path.join(
        "..", "..", "data", "raw", "older_adults", participant_name,
        f"{participant_name}_zed", f"{participant_name}_eyes_open{index}.csv")
    show_decision_trim_plots(zed_file_dir=csv_path, zed_frames=eyes_open[index - 1])
# Out:
# Index: 1
# Index: 2
# Index: 3
# Index: 4
# Index: 5

# %%
eyes_closed = [50, 50, 50, 50, 50]

# %%
for index in range(1, 6):
    print(f"Index: {index}")
    # Build the full path to the CSV, relative to notebook
    csv_path = os.path.join(
        "..", "..", "data", "raw", "older_adults", participant_name,
        f"{participant_name}_zed", f"{participant_name}_eyes_closed{index}.csv")
    show_decision_trim_plots(zed_file_dir=csv_path, zed_frames=eyes_open[index - 1])
# Out:
# Index: 1
# Index: 2
# Index: 3
# Index: 4
# Index: 5

# %%
zed_frames_dict_older_adults = {
    "ann_eyes_open1": 100,
    "ann_eyes_open3": 100,
    "ann_eyes_closed3": 100,
    "anna_eyes_open3": 100,
    "ann-m_eyes_open5": 25,
    "ann-m_eyes_closed5": 100,
    "avraham_eyes_open1": 150,
    "avraham_eyes_closed5": 100,
    "bat-sheva_eyes_open2": 100,
    "batya_eyes_open4": 100,
    "benny_eyes_open4": 20,
    "benny_eyes_closed5": 120,
    "dov_eyes_closed3": 100,
    "gita_eyes_open1": 170,
    "gita_eyes_closed2": 20,
    "gita_eyes_closed4": 20,
    "ilana_eyes_open1": 150,
    "ilana_eyes_open4": 20,
    "ilana_eyes_closed1": 80,
    "mazal_eyes_open2": 20,
    "michael_eyes_closed2": 100,
    "michael_eyes_closed3": 120,
    "miryam_eyes_closed1": 100,
    "mordehai_eyes_open2": 100,
    "naftali_eyes_open1": 150,
    "naftali_eyes_open4": 150,
    "naftali_eyes_open5": 100,
    "naomi_eyes_closed3": 100,
    "naomi_eyes_closed5": 100,
    "rahel_eyes_open4": 20,
    "raya_eyes_closed1": 100,
    "raya_eyes_closed4": 100,
    "tami_eyes_open4": 100,
    "tina_eyes_closed3": 150,
    "tova_eyes_open1": 100,
    "tova_eyes_open2": 100,
    "uri_eyes_open1": 130,
    "uri_eyes_open3": 100,
    "yaacov_eyes_open1": 80,
    "yaacov_eyes_closed1": 10,
    "yaacov_e_eyes_open5": 150,
    "yaacov_e_eyes_closed4": 100,
    "yaacov_e_eyes_closed5": 100,
    "yaffa_eyes_closed2": 20,
    "yaffa_eyes_closed4": 40,
    "yossef_eyes_open1": 150,
    "yossef_eyes_closed4": 20,
}

# %% [markdown]
# | Participant Name | Eyes Open                | Eyes Closed                        |
# |------------------|---------------------------|------------------------------------|
# | Ann              | 1:100, 3:100              | 3:100                              |
# | Anna             | 3:100                    | -                                  |
# | Ann-m            | 5:25                     | 5:100                              |
# | Avraham          | 1:150                     | 5:100                              |
# | Bat-Sheva        | 2:100                    | -                                  |
# | Batya            | 4:100                    | -                                  |
# | Benny            | 4:20                     | 5:120                              |
# | Dida             | -                        | Trial 5 eliminated, late start (from 15 s) |
# | Dov              | -                        | 3:100                              |
# | Gita             | 1:170                    | 2:20, 4:20                         |
# | Ilana            | 1:150, 4:20              | 1:80                               |
# | Mazal            | 2:20                     | -                                  |
# | Michael          | -                        | 2:100, 3:120                       |
# | Miryam           | -                        | 1:100                              |
# | Mordehai         | 2:100                    | -                                  |
# | Naftali          | 1:150, 4:150, 5:100       | No data                            |
# | Naomi            | -                        | 3:100, 5:100                       |
# | Rahel            | 4:20                     | -                                  |
# | Raya             | -                        | 1:100, 4:100                       |
# | Tami             | 4:100                    | -                                  |
# | Tina             | -                        | 3:150                              |
# | Tova             | 1:100, 2:100              |                                    |
# | Uri              | 1:130, 3:100              | -                                  |
# | Yaacov           | 1:80                     | 1:10                               |
# | Yaacov E         | 5:150                    | 4:100, 5:100                       |
# | Yaffa            | -                        | 2:20, 4:40                         |
# | Yossef           | 1:150, trial 3 eliminate        | 4:20                               |
#
#
# A Total of 47/375 session needed adjustment for their number of frames taken to calculate the mean and std.
# In addition, 2 sessions have been found insufficient.

# %% [markdown]
# # Students

# %%
id = 1

# %%
eyes_open2 = [50, 50, 50, 50, 50]

# %%
for index in range(1, 6):
    print(f"Index: {index}")
    # Build the full path to the CSV, relative to notebook
    csv_path = os.path.join(
        "..", "..", "data", "raw", "students", str(id),
        f"{id}_zed", f"{id}_eyes_open{index}.csv")
    show_decision_trim_plots(zed_file_dir=csv_path, zed_frames=eyes_open2[index - 1])
# Out:
# Index: 1
# Index: 2
# Index: 3
# Index: 4
# Index: 5

# %%
eyes_closed2 = [50, 50, 50, 50, 50]

# %%
for index in range(1, 6):
    print(f"Index: {index}")
    # Build the full path to the CSV, relative to notebook
    csv_path = os.path.join(
        "..", "..", "data", "raw", "students", str(id),
        f"{id}_zed", f"{id}_eyes_closed{index}.csv")
    show_decision_trim_plots(zed_file_dir=csv_path, zed_frames=eyes_closed2[index - 1])
# Out:
# Index: 1
# Index: 2
# Index: 3
# Index: 4
# Index: 5

# %%
zed_frames_dict_students = {
    "2_eyes_open1": 20,
    "2_eyes_open2": 20, 
    "2_eyes_open4": 20,
    "2_eyes_open5": 20, 
    "2_eyes_closed3": 30,
    "2_eyes_closed5": 30, 
    "3_eyes_closed1": 120,
    "3_eyes_closed3": 120,
    "3_eyes_closed4": 100,
    "5_eyes_open2": 100,
    "5_eyes_open3": 20,
    "8_eyes_open3": 120,
    "8_eyes_open4": 100,
    "8_eyes_closed1": 100,
    "8_eyes_closed2": 70,
    "8_eyes_closed4": 100,
    "8_eyes_closed5": 130,
    "9_eyes_closed2": 120,
    "11_eyes_closed2": 100,
    "13_eyes_open2": 120,
    "14_eyes_closed4": 100,
    "14_eyes_closed5": 100,
    "16_eyes_open2": 100,
    "18_eyes_closed2": 100,
    "19_eyes_open1": 100,
    "19_eyes_open3": 80,
    "19_eyes_closed1": 10,
    "19_eyes_closed3": 20,
    "20_eyes_open4": 100,
    "20_eyes_closed3": 20,
    "20_eyes_closed5": 100,
    "24_eyes_open1": 20
}

# %% [markdown]
# | Student ID | Eyes Open                    | Eyes Closed                                |
# |------------|-------------------------------|--------------------------------------------|
# | 2          | 1:20, 2:20, 4:20, 5:20         | 3:30, 5:30                                |
# | 3          | -                             | 1:120, 3:120, 4:100                       |
# | 5          | 2:100, 3:20                   | -                                          |
# | 6          | -                             | 3:10 (missing data from 2.2 to 6.6 seconds) |
# | 8          | 3:120, 4:100                  | 1:100, 2:70, 4:100, 5:130                 |
# | 9          | -                             | 2:120                                     |
# | 11         | -                             | 2:100                                     |
# | 13         | 2:120                         | -                                          |
# | 14         | -                             | 4:100, 5:100                              |
# | 16         | 2:100                         | -                                          |
# | 18         | -                             | 2:100                                     |
# | 19         | 1:100, 3:80                   | 1:10, 3:20                                |
# | 20         | 4:100                         | 3:20, 5:100                               |
# | 24         | 1:20                          | -                                          |
#
# A total of 32/270 sessions needed adjustments for their number of frames taken to calculate the mean and std. One session has been found insufficient.

# %%
import json

oa_json_file_path = project_root + "\data\processed\older_adults\zed_frames_dict.json"
st_json_file_path = project_root + "\data\processed\students\zed_frames_dict.json"

# Save dictionary
with open(oa_json_file_path, "w") as f:
    json.dump(zed_frames_dict_older_adults, f, indent=4)

with open(st_json_file_path, "w") as f:
    json.dump(zed_frames_dict_students, f, indent=4)
