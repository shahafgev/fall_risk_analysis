# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), "..", ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
import pandas as pd
from src.group_significance import siginificance_dataframe, plot_metrics_with_significance_side_by_side

# %%
older_adults_average_level = pd.read_csv("../../data/processed/older_adults/average_measurements.csv")
students_average_level = pd.read_csv("../../data/processed/students/average_measurements.csv")

# %%
styled_df = siginificance_dataframe(older_adults_average_level, students_average_level, alpha=0.06)
styled_df
# Out:
# c:\fall_risk_analysis\src\group_significance.py:102: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   styled = df.style.applymap(highlight_significant, subset=['Force_Plate significant', 'ZED_COM significant'])
# <style type="text/css">
# #T_71a30_row0_col4, #T_71a30_row1_col4, #T_71a30_row2_col4, #T_71a30_row3_col4, #T_71a30_row4_col4, #T_71a30_row6_col4, #T_71a30_row6_col5, #T_71a30_row7_col4, #T_71a30_row8_col4, #T_71a30_row10_col4, #T_71a30_row12_col4, #T_71a30_row13_col4, #T_71a30_row15_col4, #T_71a30_row17_col4, #T_71a30_row17_col5, #T_71a30_row18_col4, #T_71a30_row18_col5, #T_71a30_row19_col4, #T_71a30_row21_col4 {
#   background-color: green;
# }
# </style>
# <table id="T_71a30">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_71a30_level0_col0" class="col_heading level0 col0" >State</th>
#       <th id="T_71a30_level0_col1" class="col_heading level0 col1" >Metric</th>
#       <th id="T_71a30_level0_col2" class="col_heading level0 col2" >P-value Force_Plate</th>
#       <th id="T_71a30_level0_col3" class="col_heading level0 col3" >P-value ZED_COM</th>
#       <th id="T_71a30_level0_col4" class="col_heading level0 col4" >Force_Plate significant</th>
#       <th id="T_71a30_level0_col5" class="col_heading level0 col5" >ZED_COM significant</th>
#       <th id="T_71a30_level0_col6" class="col_heading level0 col6" >Force_Plate test used</th>
#       <th id="T_71a30_level0_col7" class="col_heading level0 col7" >ZED_COM test used</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_71a30_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_71a30_row0_col0" class="data row0 col0" >closed</td>
#       <td id="T_71a30_row0_col1" class="data row0 col1" >AP MAD</td>
#       <td id="T_71a30_row0_col2" class="data row0 col2" >0.053562</td>
#       <td id="T_71a30_row0_col3" class="data row0 col3" >0.723753</td>
#       <td id="T_71a30_row0_col4" class="data row0 col4" >True</td>
#       <td id="T_71a30_row0_col5" class="data row0 col5" >False</td>
#       <td id="T_71a30_row0_col6" class="data row0 col6" >Mann-Whitney</td>
#       <td id="T_71a30_row0_col7" class="data row0 col7" >Mann-Whitney</td>
#     </tr>
#     <tr>
#       <th id="T_71a30_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_71a30_row1_col0" class="data row1 col0" >closed</td>
#       <td id="T_71a30_row1_col1" class="data row1 col1" >AP Max abs dev</td>
#       <td id="T_71a30_row1_col2" class="data row1 col2" >0.003624</td>
#       <td id="T_71a30_row1_col3" class="data row1 col3" >0.355278</td>
#       <td id="T_71a30_row1_col4" class="data row1 col4" >True</td>
#       <td id="T_71a30_row1_col5" class="data row1 col5" >False</td>
#       <td id="T_71a30_row1_col6" class="data row1 col6" >Mann-Whitney</td>
#       <td id="T_71a30_row1_col7" class="data row1 col7" >Mann-Whitney</td>
#     </tr>
#     <tr>
#       <th id="T_71a30_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_71a30_row2_col0" class="data row2 col0" >closed</td>
#       <td id="T_71a30_row2_col1" class="data row2 col1" >AP Range</td>
#       <td id="T_71a30_row2_col2" class="data row2 col2" >0.005551</td>
#       <td id="T_71a30_row2_col3" class="data row2 col3" >0.307938</td>
#       <td id="T_71a30_row2_col4" class="data row2 col4" >True</td>
#       <td id="T_71a30_row2_col5" class="data row2 col5" >False</td>
#       <td id="T_71a30_row2_col6" class="data row2 col6" >Mann-Whitney</td>
#       <td id="T_71a30_row2_col7" class="data row2 col7" >Mann-Whitney</td>
#     </tr>
#     <tr>
#       <th id="T_71a30_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_71a30_row3_col0" class="data row3 col0" >closed</td>
#       <td id="T_71a30_row3_col1" class="data row3 col1" >AP Variance</td>
#       <td id="T_71a30_row3_col2" class="data row3 col2" >0.055267</td>
#       <td id="T_71a30_row3_col3" class="data row3 col3" >0.643938</td>
#       <td id="T_71a30_row3_col4" class="data row3 col4" >True</td>
#       <td id="T_71a30_row3_col5" class="data row3 col5" >False</td>
#       <td id="T_71a30_row3_col6" class="data row3 col6" >Mann-Whitney</td>
#       <td id="T_71a30_row3_col7" class="data row3 col7" >Mann-Whitney</td>
#     </tr>
#     <tr>
#       <th id="T_71a30_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_71a30_row4_col0" class="data row4 col0" >closed</td>
#       <td id="T_71a30_row4_col1" class="data row4 col1" >Ellipse area</td>
#       <td id="T_71a30_row4_col2" class="data row4 col2" >0.013873</td>
#       <td id="T_71a30_row4_col3" class="data row4 col3" >0.206139</td>
#       <td id="T_71a30_row4_col4" class="data row4 col4" >True</td>
#       <td id="T_71a30_row4_col5" class="data row4 col5" >False</td>
#       <td id="T_71a30_row4_col6" class="data row4 col6" >Mann-Whitney</td>
#       <td id="T_71a30_row4_col7" class="data row4 col7" >Mann-Whitney</td>
#     </tr>
#     <tr>
#       <th id="T_71a30_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_71a30_row5_col0" class="data row5 col0" >closed</td>
#       <td id="T_71a30_row5_col1" class="data row5 col1" >ML MAD</td>
#       <td id="T_71a30_row5_col2" class="data row5 col2" >0.070604</td>
#       <td id="T_71a30_row5_col3" class="data row5 col3" >0.108691</td>
#       <td id="T_71a30_row5_col4" class="data row5 col4" >False</td>
#       <td id="T_71a30_row5_col5" class="data row5 col5" >False</td>
#       <td id="T_71a30_row5_col6" class="data row5 col6" >Mann-Whitney</td>
#       <td id="T_71a30_row5_col7" class="data row5 col7" >Mann-Whitney</td>
#     </tr>
#     <tr>
#       <th id="T_71a30_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_71a30_row6_col0" class="data row6 col0" >closed</td>
#       <td id="T_71a30_row6_col1" class="data row6 col1" >ML Max abs dev</td>
#       <td id="T_71a30_row6_col2" class="data row6 col2" >0.000955</td>
#       <td id="T_71a30_row6_col3" class="data row6 col3" >0.042814</td>
#       <td id="T_71a30_row6_col4" class="data row6 col4" >True</td>
#       <td id="T_71a30_row6_col5" class="data row6 col5" >True</td>
#       <td id="T_71a30_row6_col6" class="data row6 col6" >Mann-Whitney</td>
#       <td id="T_71a30_row6_col7" class="data row6 col7" >Mann-Whitney</td>
#     </tr>
#     <tr>
#       <th id="T_71a30_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_71a30_row7_col0" class="data row7 col0" >closed</td>
#       <td id="T_71a30_row7_col1" class="data row7 col1" >ML Range</td>
#       <td id="T_71a30_row7_col2" class="data row7 col2" >0.001688</td>
#       <td id="T_71a30_row7_col3" class="data row7 col3" >0.062547</td>
#       <td id="T_71a30_row7_col4" class="data row7 col4" >True</td>
#       <td id="T_71a30_row7_col5" class="data row7 col5" >False</td>
#       <td id="T_71a30_row7_col6" class="data row7 col6" >Mann-Whitney</td>
#       <td id="T_71a30_row7_col7" class="data row7 col7" >Mann-Whitney</td>
#     </tr>
#     <tr>
#       <th id="T_71a30_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_71a30_row8_col0" class="data row8 col0" >closed</td>
#       <td id="T_71a30_row8_col1" class="data row8 col1" >ML Variance</td>
#       <td id="T_71a30_row8_col2" class="data row8 col2" >0.024895</td>
#       <td id="T_71a30_row8_col3" class="data row8 col3" >0.111719</td>
#       <td id="T_71a30_row8_col4" class="data row8 col4" >True</td>
#       <td id="T_71a30_row8_col5" class="data row8 col5" >False</td>
#       <td id="T_71a30_row8_col6" class="data row8 col6" >Mann-Whitney</td>
#       <td id="T_71a30_row8_col7" class="data row8 col7" >Mann-Whitney</td>
#     </tr>
#     <tr>
#       <th id="T_71a30_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_71a30_row9_col0" class="data row9 col0" >closed</td>
#       <td id="T_71a30_row9_col1" class="data row9 col1" >Path length</td>
#       <td id="T_71a30_row9_col2" class="data row9 col2" >0.764886</td>
#       <td id="T_71a30_row9_col3" class="data row9 col3" >0.733967</td>
#       <td id="T_71a30_row9_col4" class="data row9 col4" >False</td>
#       <td id="T_71a30_row9_col5" class="data row9 col5" >False</td>
#       <td id="T_71a30_row9_col6" class="data row9 col6" >Mann-Whitney</td>
#       <td id="T_71a30_row9_col7" class="data row9 col7" >Mann-Whitney</td>
#     </tr>
#     <tr>
#       <th id="T_71a30_level0_row10" class="row_heading level0 row10" >10</

# %%
plot_metrics_with_significance_side_by_side(state='open', device='Force_Plate', df1=older_adults_average_level, df2=students_average_level, 
                                            group1_label='Older Adults', group2_label='Students',alpha=0.06)

# %%
plot_metrics_with_significance_side_by_side(state='closed', device='Force_Plate', df1=older_adults_average_level, df2=students_average_level, 
                                            group1_label='Older Adults', group2_label='Students',alpha=0.06)

# %%
plot_metrics_with_significance_side_by_side(state='open', device='ZED_COM', df1=older_adults_average_level, df2=students_average_level, 
                                            group1_label='Older Adults', group2_label='Students',alpha=0.06)

# %%
plot_metrics_with_significance_side_by_side(state='closed', device='ZED_COM', df1=older_adults_average_level, df2=students_average_level, 
                                            group1_label='Older Adults', group2_label='Students',alpha=0.06)
