# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), "..", ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
from src.mape import plot_mape_heatmap, plot_mape_change_bars
import pandas as pd

# %% [markdown]
# # Older Adults

# %%
older_adults_trial_level = pd.read_csv("../../data/processed/older_adults/filtered_measurements.csv")
older_adults_average_level = pd.read_csv("../../data/processed/older_adults/average_measurements.csv")

# %% [markdown]
# ### Trial-level

# %%
plot_mape_heatmap(older_adults_trial_level)

# %% [markdown]
# ### Average-level

# %%
plot_mape_heatmap(older_adults_average_level)

# %%
plot_mape_change_bars(older_adults_trial_level, older_adults_average_level)

# %% [markdown]
# # Students

# %%
students_trial_level = pd.read_csv("../../data/processed/students/measurements.csv")
students_average_level = pd.read_csv("../../data/processed/students/average_measurements.csv")

# %% [markdown]
# ### Trial-level

# %%
plot_mape_heatmap(students_trial_level)

# %% [markdown]
# ### Average-level

# %%
plot_mape_heatmap(students_average_level)

# %%
plot_mape_change_bars(students_trial_level, students_average_level)
