# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), "..", ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
from src.bland_altman import bland_altman_plot_by_state
import pandas as pd

# %%
older_adults_trial_level = pd.read_csv("../../data/processed/older_adults/filtered_measurements.csv")
older_adults_average_level = pd.read_csv("../../data/processed/older_adults/average_measurements.csv")
students_trial_level = pd.read_csv("../../data/processed/students/measurements.csv")
students_average_level = pd.read_csv("../../data/processed/students/average_measurements.csv")

# %% [markdown]
# ## AP MAD

# %% [markdown]
# ### Older Adults

# %%
bland_altman_plot_by_state(df=older_adults_trial_level, metric_name="AP MAD", source_name="oa_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:75: UserWarning: Precomputed assumption: non-normal distribution for AP MAD (eyes closed). Using non-parametric LOA.
#   warnings.warn(f"Precomputed assumption: non-normal distribution for {metric_name} (eyes {st}). Using non-parametric LOA.")
# c:\fall_risk_analysis\src\bland_altman.py:75: UserWarning: Precomputed assumption: non-normal distribution for AP MAD (eyes open). Using non-parametric LOA.
#   warnings.warn(f"Precomputed assumption: non-normal distribution for {metric_name} (eyes {st}). Using non-parametric LOA.")

# %%
bland_altman_plot_by_state(older_adults_average_level, "AP MAD", average_level=True, source_name="oa_average")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for AP MAD (eyes open). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")

# %% [markdown]
# ### Students

# %%
bland_altman_plot_by_state(students_trial_level, "AP MAD", source_name="st_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:75: UserWarning: Precomputed assumption: non-normal distribution for AP MAD (eyes closed). Using non-parametric LOA.
#   warnings.warn(f"Precomputed assumption: non-normal distribution for {metric_name} (eyes {st}). Using non-parametric LOA.")

# %%
bland_altman_plot_by_state(students_average_level, "AP MAD", average_level=True,source_name="st_average")

# %% [markdown]
# ## AP Max abs dev

# %% [markdown]
# ### Older Adults

# %%
bland_altman_plot_by_state(older_adults_trial_level, "AP Max abs dev", source_name="oa_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for AP Max abs dev (eyes closed). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for AP Max abs dev (eyes open). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")

# %%
bland_altman_plot_by_state(older_adults_average_level, "AP Max abs dev", average_level=True, source_name="oa_average")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for AP Max abs dev (eyes closed). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for AP Max abs dev (eyes open). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")

# %% [markdown]
# ### Students

# %%
bland_altman_plot_by_state(students_trial_level, "AP Max abs dev", source_name="st_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:75: UserWarning: Precomputed assumption: non-normal distribution for AP Max abs dev (eyes closed). Using non-parametric LOA.
#   warnings.warn(f"Precomputed assumption: non-normal distribution for {metric_name} (eyes {st}). Using non-parametric LOA.")
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for AP Max abs dev (eyes open). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")

# %%
bland_altman_plot_by_state(students_average_level, "AP Max abs dev", average_level=True, source_name="st_average")

# %% [markdown]
# ## AP Range

# %% [markdown]
# ### Older Adults

# %%
bland_altman_plot_by_state(older_adults_trial_level, "AP Range", source_name="oa_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for AP Range (eyes closed). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for AP Range (eyes open). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")

# %%
bland_altman_plot_by_state(older_adults_average_level, "AP Range", average_level=True, source_name="oa_average")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for AP Range (eyes closed). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for AP Range (eyes open). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")

# %% [markdown]
# ### Students

# %%
bland_altman_plot_by_state(students_trial_level, "AP Range", source_name="st_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for AP Range (eyes open). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")

# %%
bland_altman_plot_by_state(students_average_level, "AP Range", average_level=True, source_name="st_average")

# %% [markdown]
# ## AP Variance

# %% [markdown]
# ### Older Adults

# %%
bland_altman_plot_by_state(older_adults_trial_level, "AP Variance", source_name="oa_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for AP Variance (eyes closed). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for AP Variance (eyes open). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")

# %%
bland_altman_plot_by_state(older_adults_average_level, "AP Variance", average_level=True, source_name="oa_average")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for AP Variance (eyes closed). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for AP Variance (eyes open). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")

# %% [markdown]
# ### Students

# %%
bland_altman_plot_by_state(students_trial_level, "AP Variance", source_name="st_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for AP Variance (eyes closed). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for AP Variance (eyes open). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")

# %%
bland_altman_plot_by_state(students_average_level, "AP Variance", average_level=True, source_name="st_average")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for AP Variance (eyes open). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")

# %% [markdown]
# ## Ellipse area

# %% [markdown]
# ### Older Adults

# %%
bland_altman_plot_by_state(older_adults_trial_level, "Ellipse area", source_name="oa_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for Ellipse area (eyes closed). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for Ellipse area (eyes open). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")

# %%
bland_altman_plot_by_state(older_adults_average_level, "Ellipse area", average_level=True, source_name="oa_average")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for Ellipse area (eyes closed). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for Ellipse area (eyes open). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")

# %% [markdown]
# ### Students

# %%
bland_altman_plot_by_state(students_trial_level, "Ellipse area", source_name="st_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for Ellipse area (eyes closed). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for Ellipse area (eyes open). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")

# %%
bland_altman_plot_by_state(students_average_level, "Ellipse area", average_level=True, source_name="st_average")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for Ellipse area (eyes open). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")

# %% [markdown]
# ## ML MAD

# %% [markdown]
# ### Older Adults

# %%
bland_altman_plot_by_state(older_adults_trial_level, "ML MAD", source_name="oa_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for ML MAD (eyes open). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")

# %%
bland_altman_plot_by_state(older_adults_average_level, "ML MAD", average_level=True, source_name="oa_average")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for ML MAD (eyes open). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")

# %% [markdown]
# ### Students

# %%
bland_altman_plot_by_state(students_trial_level, "ML MAD", source_name="st_trial")

# %%
bland_altman_plot_by_state(students_average_level, "ML MAD", average_level=True, source_name="st_average")

# %% [markdown]
# ## ML Max abs dev

# %% [markdown]
# ### Older Adults

# %%
bland_altman_plot_by_state(older_adults_trial_level, "ML Max abs dev", source_name="oa_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for ML Max abs dev (eyes closed). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for ML Max abs dev (eyes open). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")

# %%
bland_altman_plot_by_state(older_adults_average_level, "ML Max abs dev", average_level=True, source_name="oa_average")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for ML Max abs dev (eyes closed). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for ML Max abs dev (eyes open). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")

# %% [markdown]
# ### Students

# %%
bland_altman_plot_by_state(students_trial_level, "ML Max abs dev", source_name="st_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:75: UserWarning: Precomputed assumption: non-normal distribution for ML Max abs dev (eyes closed). Using non-parametric LOA.
#   warnings.warn(f"Precomputed assumption: non-normal distribution for {metric_name} (eyes {st}). Using non-parametric LOA.")
# c:\fall_risk_analysis\src\bland_altman.py:75: UserWarning: Precomputed assumption: non-normal distribution for ML Max abs dev (eyes open). Using non-parametric LOA.
#   warnings.warn(f"Precomputed assumption: non-normal distribution for {metric_name} (eyes {st}). Using non-parametric LOA.")

# %%
bland_altman_plot_by_state(students_average_level, "ML Max abs dev", average_level=True, source_name="st_average")

# %% [markdown]
# ## ML Range

# %% [markdown]
# ### Older Adults

# %%
bland_altman_plot_by_state(older_adults_trial_level, "ML Range", source_name="oa_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for ML Range (eyes closed). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for ML Range (eyes open). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")

# %%
bland_altman_plot_by_state(older_adults_average_level, "ML Range", average_level=True, source_name="oa_average")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for ML Range (eyes closed). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for ML Range (eyes open). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")

# %% [markdown]
# ### Students

# %%
bland_altman_plot_by_state(students_trial_level, "ML Range", source_name="st_trial")

# %%
bland_altman_plot_by_state(students_average_level, "ML Range", average_level=True, source_name="st_average")

# %% [markdown]
# ## ML Variance

# %% [markdown]
# ### Older Adults

# %%
bland_altman_plot_by_state(older_adults_trial_level, "ML Variance", source_name="oa_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for ML Variance (eyes closed). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for ML Variance (eyes open). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")

# %%
bland_altman_plot_by_state(older_adults_average_level, "ML Variance", average_level=True, source_name="oa_average")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for ML Variance (eyes closed). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for ML Variance (eyes open). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")

# %% [markdown]
# ### Students

# %%
bland_altman_plot_by_state(students_trial_level, "ML Variance", source_name="st_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for ML Variance (eyes closed). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for ML Variance (eyes open). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")

# %%
bland_altman_plot_by_state(students_average_level, "ML Variance", average_level=True, source_name="st_average")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for ML Variance (eyes open). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")

# %% [markdown]
# ## Path length

# %% [markdown]
# ### Older Adults

# %%
bland_altman_plot_by_state(older_adults_trial_level, "Path length", source_name="oa_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for Path length (eyes closed). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for Path length (eyes open). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")

# %%
bland_altman_plot_by_state(older_adults_average_level, "Path length", average_level=True, source_name="oa_average")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for Path length (eyes closed). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for Path length (eyes open). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")

# %% [markdown]
# ### Students

# %%
bland_altman_plot_by_state(students_trial_level, "Path length", source_name="st_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for Path length (eyes closed). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for Path length (eyes open). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")

# %%
bland_altman_plot_by_state(students_average_level, "Path length", average_level=True, source_name="st_average")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for Path length (eyes closed). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for Path length (eyes open). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")

# %% [markdown]
# ## Sway RMS

# %% [markdown]
# ### Older Adults

# %%
bland_altman_plot_by_state(older_adults_trial_level, "Sway RMS", source_name="oa_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for Sway RMS (eyes closed). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for Sway RMS (eyes open). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")

# %%
bland_altman_plot_by_state(older_adults_average_level, "Sway RMS", average_level=True, source_name="oa_average")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for Sway RMS (eyes closed). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")
# c:\fall_risk_analysis\src\bland_altman.py:78: UserWarning: Precomputed assumption: heteroscedasticity detected for Sway RMS (eyes open). Consider log transformation.
#   warnings.warn(f"Precomputed assumption: heteroscedasticity detected for {metric_name} (eyes {st}). Consider log transformation.")

# %% [markdown]
# ### Students

# %%
bland_altman_plot_by_state(students_trial_level, "Sway RMS", source_name="st_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:75: UserWarning: Precomputed assumption: non-normal distribution for Sway RMS (eyes closed). Using non-parametric LOA.
#   warnings.warn(f"Precomputed assumption: non-normal distribution for {metric_name} (eyes {st}). Using non-parametric LOA.")

# %%
bland_altman_plot_by_state(students_average_level, "Sway RMS", average_level=True, source_name="st_average")
