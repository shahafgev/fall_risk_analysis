# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), "..", ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
from src.bland_altman import bland_altman_plot_by_state
import pandas as pd

# %%
metrics_to_plot = ["AP MAD", "AP Max abs dev", "AP Range", "AP Variance",
                   "Ellipse area",
                  "ML MAD", "ML Max abs dev", "ML Range", "ML Variance",
                  "Path length", "Sway RMS"]

# %%
older_adults_trial_level = pd.read_csv("../../data/processed/older_adults/filtered_measurements.csv")
older_adults_average_level = pd.read_csv("../../data/processed/older_adults/average_measurements.csv")
students_trial_level = pd.read_csv("../../data/processed/students/measurements.csv")
students_average_level = pd.read_csv("../../data/processed/students/average_measurements.csv")

# %% [markdown]
# ## AP MAD

# %% [markdown]
# ### Older Adults

# %%
bland_altman_plot_by_state(older_adults_trial_level, "AP MAD")
bland_altman_plot_by_state(older_adults_average_level, "AP MAD", average_level=True)

# %% [markdown]
# ### Students

# %%
bland_altman_plot_by_state(students_trial_level, "AP MAD")
bland_altman_plot_by_state(students_average_level, "AP MAD", average_level=True)

# %% [markdown]
# ## AP Max abs dev

# %% [markdown]
# ### Older Adults

# %%
bland_altman_plot_by_state(older_adults_trial_level, "AP Max abs dev")
bland_altman_plot_by_state(older_adults_average_level, "AP Max abs dev", average_level=True)

# %% [markdown]
# ### Students

# %%
bland_altman_plot_by_state(students_trial_level, "AP Max abs dev")
bland_altman_plot_by_state(students_average_level, "AP Max abs dev", average_level=True)

# %% [markdown]
# ## AP Range

# %% [markdown]
# ### Older Adults

# %%
bland_altman_plot_by_state(older_adults_trial_level, "AP Range")
bland_altman_plot_by_state(older_adults_average_level, "AP Range", average_level=True)

# %% [markdown]
# ### Students

# %%
bland_altman_plot_by_state(students_trial_level, "AP Range")
bland_altman_plot_by_state(students_average_level, "AP Range", average_level=True)

# %% [markdown]
# ## AP Variance

# %% [markdown]
# ### Older Adults

# %%
bland_altman_plot_by_state(older_adults_trial_level, "AP Variance")
bland_altman_plot_by_state(older_adults_average_level, "AP Variance", average_level=True)

# %% [markdown]
# ### Students

# %%
bland_altman_plot_by_state(students_trial_level, "AP Variance")
bland_altman_plot_by_state(students_average_level, "AP Variance", average_level=True)

# %% [markdown]
# ## Ellipse area

# %% [markdown]
# ### Older Adults

# %%
bland_altman_plot_by_state(older_adults_trial_level, "Ellipse area")
bland_altman_plot_by_state(older_adults_average_level, "Ellipse area", average_level=True)

# %% [markdown]
# ### Students

# %%
bland_altman_plot_by_state(students_trial_level, "Ellipse area")
bland_altman_plot_by_state(students_average_level, "Ellipse area", average_level=True)

# %% [markdown]
# ## ML MAD

# %% [markdown]
# ### Older Adults

# %%
bland_altman_plot_by_state(older_adults_trial_level, "ML MAD")
bland_altman_plot_by_state(older_adults_average_level, "ML MAD", average_level=True)

# %% [markdown]
# ### Students

# %%
bland_altman_plot_by_state(students_trial_level, "ML MAD")
bland_altman_plot_by_state(students_average_level, "ML MAD", average_level=True)

# %% [markdown]
# ## ML Max abs dev

# %% [markdown]
# ### Older Adults

# %%
bland_altman_plot_by_state(older_adults_trial_level, "ML Max abs dev")
bland_altman_plot_by_state(older_adults_average_level, "ML Max abs dev", average_level=True)

# %% [markdown]
# ### Students

# %%
bland_altman_plot_by_state(students_trial_level, "ML Max abs dev")
bland_altman_plot_by_state(students_average_level, "ML Max abs dev", average_level=True)

# %% [markdown]
# ## ML Range

# %% [markdown]
# ### Older Adults

# %%
bland_altman_plot_by_state(older_adults_trial_level, "ML Range")
bland_altman_plot_by_state(older_adults_average_level, "ML Range", average_level=True)

# %% [markdown]
# ### Students

# %%
bland_altman_plot_by_state(students_trial_level, "ML Range")
bland_altman_plot_by_state(students_average_level, "ML Range", average_level=True)

# %% [markdown]
# ## ML Variance

# %% [markdown]
# ### Older Adults

# %%
bland_altman_plot_by_state(older_adults_trial_level, "ML Variance")
bland_altman_plot_by_state(older_adults_average_level, "ML Variance", average_level=True)

# %% [markdown]
# ### Students

# %%
bland_altman_plot_by_state(students_trial_level, "ML Variance")
bland_altman_plot_by_state(students_average_level, "ML Variance", average_level=True)

# %% [markdown]
# ## Path length

# %% [markdown]
# ### Older Adults

# %%
bland_altman_plot_by_state(older_adults_trial_level, "Path length")
bland_altman_plot_by_state(older_adults_average_level, "Path length", average_level=True)

# %% [markdown]
# ### Students

# %%
bland_altman_plot_by_state(students_trial_level, "Path length")
bland_altman_plot_by_state(students_average_level, "Path length", average_level=True)

# %% [markdown]
# ## Sway RMS

# %% [markdown]
# ### Older Adults

# %%
bland_altman_plot_by_state(older_adults_trial_level, "Sway RMS")
bland_altman_plot_by_state(older_adults_average_level, "Sway RMS", average_level=True)

# %% [markdown]
# ### Students

# %%
bland_altman_plot_by_state(students_trial_level, "Sway RMS")
bland_altman_plot_by_state(students_average_level, "Sway RMS", average_level=True)
