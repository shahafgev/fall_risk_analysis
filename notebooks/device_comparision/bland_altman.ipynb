# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), "..", ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
from src.bland_altman import bland_altman_plot_by_state
import pandas as pd

# %%
older_adults_trial_level = pd.read_csv("../../data/processed/older_adults/filtered_measurements.csv")
older_adults_average_level = pd.read_csv("../../data/processed/older_adults/average_measurements.csv")
students_trial_level = pd.read_csv("../../data/processed/students/measurements.csv")
students_average_level = pd.read_csv("../../data/processed/students/average_measurements.csv")

# %% [markdown]
# ## AP MAD

# %% [markdown]
# ### Older Adults

# %%
bland_altman_plot_by_state(df=older_adults_trial_level, metric_name="AP MAD", source_name="oa_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'AP MAD' (closed state): non-normal distribution. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'AP MAD' (open state): non-normal distribution. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(

# %%
bland_altman_plot_by_state(older_adults_average_level, "AP MAD", average_level=True, source_name="oa_average")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'AP MAD' (open state): heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(

# %% [markdown]
# ### Students

# %%
bland_altman_plot_by_state(students_trial_level, "AP MAD", source_name="st_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'AP MAD' (closed state): non-normal distribution. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(

# %%
bland_altman_plot_by_state(students_average_level, "AP MAD", average_level=True,source_name="st_average")

# %% [markdown]
# ## AP Max abs dev

# %% [markdown]
# ### Older Adults

# %%
bland_altman_plot_by_state(older_adults_trial_level, "AP Max abs dev", source_name="oa_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'AP Max abs dev' (closed state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'AP Max abs dev' (open state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(

# %%
bland_altman_plot_by_state(older_adults_average_level, "AP Max abs dev", average_level=True, source_name="oa_average")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'AP Max abs dev' (closed state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'AP Max abs dev' (open state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(

# %% [markdown]
# ### Students

# %%
bland_altman_plot_by_state(students_trial_level, "AP Max abs dev", source_name="st_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'AP Max abs dev' (closed state): non-normal distribution. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'AP Max abs dev' (open state): heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(

# %%
bland_altman_plot_by_state(students_average_level, "AP Max abs dev", average_level=True, source_name="st_average")

# %% [markdown]
# ## AP Range

# %% [markdown]
# ### Older Adults

# %%
bland_altman_plot_by_state(older_adults_trial_level, "AP Range", source_name="oa_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'AP Range' (closed state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'AP Range' (open state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(

# %%
bland_altman_plot_by_state(older_adults_average_level, "AP Range", average_level=True, source_name="oa_average")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'AP Range' (closed state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'AP Range' (open state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(

# %% [markdown]
# ### Students

# %%
bland_altman_plot_by_state(students_trial_level, "AP Range", source_name="st_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'AP Range' (open state): heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(

# %%
bland_altman_plot_by_state(students_average_level, "AP Range", average_level=True, source_name="st_average")

# %% [markdown]
# ## AP Variance

# %% [markdown]
# ### Older Adults

# %%
bland_altman_plot_by_state(older_adults_trial_level, "AP Variance", source_name="oa_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'AP Variance' (closed state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'AP Variance' (open state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(

# %%
bland_altman_plot_by_state(older_adults_average_level, "AP Variance", average_level=True, source_name="oa_average")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'AP Variance' (closed state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'AP Variance' (open state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(

# %% [markdown]
# ### Students

# %%
bland_altman_plot_by_state(students_trial_level, "AP Variance", source_name="st_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'AP Variance' (closed state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'AP Variance' (open state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(

# %%
bland_altman_plot_by_state(students_average_level, "AP Variance", average_level=True, source_name="st_average")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'AP Variance' (open state): heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(

# %% [markdown]
# ## Ellipse area

# %% [markdown]
# ### Older Adults

# %%
bland_altman_plot_by_state(older_adults_trial_level, "Ellipse area", source_name="oa_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'Ellipse area' (closed state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'Ellipse area' (open state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(

# %%
bland_altman_plot_by_state(older_adults_average_level, "Ellipse area", average_level=True, source_name="oa_average")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'Ellipse area' (closed state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'Ellipse area' (open state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(

# %% [markdown]
# ### Students

# %%
bland_altman_plot_by_state(students_trial_level, "Ellipse area", source_name="st_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'Ellipse area' (closed state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'Ellipse area' (open state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(

# %%
bland_altman_plot_by_state(students_average_level, "Ellipse area", average_level=True, source_name="st_average")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'Ellipse area' (open state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(

# %% [markdown]
# ## ML MAD

# %% [markdown]
# ### Older Adults

# %%
bland_altman_plot_by_state(older_adults_trial_level, "ML MAD", source_name="oa_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'ML MAD' (open state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(

# %%
bland_altman_plot_by_state(older_adults_average_level, "ML MAD", average_level=True, source_name="oa_average")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'ML MAD' (open state): heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(

# %% [markdown]
# ### Students

# %%
bland_altman_plot_by_state(students_trial_level, "ML MAD", source_name="st_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'ML MAD' (closed state): heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(

# %%
bland_altman_plot_by_state(students_average_level, "ML MAD", average_level=True, source_name="st_average")

# %% [markdown]
# ## ML Max abs dev

# %% [markdown]
# ### Older Adults

# %%
bland_altman_plot_by_state(older_adults_trial_level, "ML Max abs dev", source_name="oa_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'ML Max abs dev' (closed state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'ML Max abs dev' (open state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(

# %%
bland_altman_plot_by_state(older_adults_average_level, "ML Max abs dev", average_level=True, source_name="oa_average")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'ML Max abs dev' (closed state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'ML Max abs dev' (open state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(

# %% [markdown]
# ### Students

# %%
bland_altman_plot_by_state(students_trial_level, "ML Max abs dev", source_name="st_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'ML Max abs dev' (closed state): non-normal distribution. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'ML Max abs dev' (open state): non-normal distribution. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(

# %%
bland_altman_plot_by_state(students_average_level, "ML Max abs dev", average_level=True, source_name="st_average")

# %% [markdown]
# ## ML Range

# %% [markdown]
# ### Older Adults

# %%
bland_altman_plot_by_state(older_adults_trial_level, "ML Range", source_name="oa_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'ML Range' (closed state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'ML Range' (open state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(

# %%
bland_altman_plot_by_state(older_adults_average_level, "ML Range", average_level=True, source_name="oa_average")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'ML Range' (closed state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'ML Range' (open state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(

# %% [markdown]
# ### Students

# %%
bland_altman_plot_by_state(students_trial_level, "ML Range", source_name="st_trial")

# %%
bland_altman_plot_by_state(students_average_level, "ML Range", average_level=True, source_name="st_average")

# %% [markdown]
# ## ML Variance

# %% [markdown]
# ### Older Adults

# %%
bland_altman_plot_by_state(older_adults_trial_level, "ML Variance", source_name="oa_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'ML Variance' (closed state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'ML Variance' (open state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(

# %%
bland_altman_plot_by_state(older_adults_average_level, "ML Variance", average_level=True, source_name="oa_average")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'ML Variance' (closed state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'ML Variance' (open state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(

# %% [markdown]
# ### Students

# %%
bland_altman_plot_by_state(students_trial_level, "ML Variance", source_name="st_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'ML Variance' (closed state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'ML Variance' (open state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(

# %%
bland_altman_plot_by_state(students_average_level, "ML Variance", average_level=True, source_name="st_average")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'ML Variance' (open state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(

# %% [markdown]
# ## Path length

# %% [markdown]
# ### Older Adults

# %%
bland_altman_plot_by_state(older_adults_trial_level, "Path length", source_name="oa_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'Path length' (closed state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'Path length' (open state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(

# %%
bland_altman_plot_by_state(older_adults_average_level, "Path length", average_level=True, source_name="oa_average")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'Path length' (closed state): heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'Path length' (open state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(

# %% [markdown]
# ### Students

# %%
bland_altman_plot_by_state(students_trial_level, "Path length", source_name="st_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'Path length' (closed state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'Path length' (open state): heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(

# %%
bland_altman_plot_by_state(students_average_level, "Path length", average_level=True, source_name="st_average")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'Path length' (closed state): heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'Path length' (open state): heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(

# %% [markdown]
# ## Sway RMS

# %% [markdown]
# ### Older Adults

# %%
bland_altman_plot_by_state(older_adults_trial_level, "Sway RMS", source_name="oa_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'Sway RMS' (closed state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'Sway RMS' (open state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(

# %%
bland_altman_plot_by_state(older_adults_average_level, "Sway RMS", average_level=True, source_name="oa_average")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'Sway RMS' (closed state): heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'Sway RMS' (open state): non-normal distribution and heteroscedasticity. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(

# %% [markdown]
# ### Students

# %%
bland_altman_plot_by_state(students_trial_level, "Sway RMS", source_name="st_trial")
# Out:
# c:\fall_risk_analysis\src\bland_altman.py:83: UserWarning: Precomputed assumption violation for 'Sway RMS' (closed state): non-normal distribution. Using non-parametric LOA or interpret results with caution.
#   warnings.warn(

# %%
bland_altman_plot_by_state(students_average_level, "Sway RMS", average_level=True, source_name="st_average")
