# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), "..", ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
from src.residuals import plot_residuals_by_metric_and_state
import pandas as pd

# %% [markdown]
# # Older Adults

# %%
older_adults_trial_level = pd.read_csv("../../data/processed/older_adults/filtered_measurements.csv")
older_adults_average_level = pd.read_csv("../../data/processed/older_adults/average_measurements.csv")

# %% [markdown]
# ### Trial-level

# %%
plot_residuals_by_metric_and_state(older_adults_trial_level)

# %% [markdown]
# ### Average-level

# %%
plot_residuals_by_metric_and_state(older_adults_average_level, average_level=True)

# %% [markdown]
# # Students

# %%
students_trial_level = pd.read_csv("../../data/processed/students/measurements.csv")
students_average_level = pd.read_csv("../../data/processed/students/average_measurements.csv")

# %% [markdown]
# ### Trial-level

# %%
plot_residuals_by_metric_and_state(students_trial_level)

# %% [markdown]
# ### Average-level

# %%
plot_residuals_by_metric_and_state(students_average_level, average_level=True)
