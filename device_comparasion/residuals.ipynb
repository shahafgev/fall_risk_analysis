# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
from src.regression import plot_regression_and_residuals
import pandas as pd

# %% [markdown]
# # Older Adults

# %%
older_adults_average_level = pd.read_csv("../data/processed/older_adults/average_measurements.csv")

# %% [markdown]
# ### Average-level

# %%
for metric in older_adults_average_level["metric"].unique():
    for state in ("open", "closed"):
        plot_regression_and_residuals(older_adults_average_level, metric, state)

# %% [markdown]
# # Students

# %%
students_average_level = pd.read_csv("../data/processed/students/average_measurements.csv")

# %% [markdown]
# ### Average-level

# %%
for metric in students_average_level["metric"].unique():
    for state in ("open", "closed"):
        plot_regression_and_residuals(students_average_level, metric, state)
