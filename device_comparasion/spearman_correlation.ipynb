# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
from src.correlation import plot_corrleations_heatmap, plot_state_difference_in_correlations, plot_correlation_change_bars
import pandas as pd

# %%
exclude_metrics = ["Range Ratio", "Path length"]
row_order = [
    "AP Range", "ML Range", "AP MAD", "ML MAD", "AP Max abs dev", 
    "ML Max abs dev", "AP RMS", "ML RMS", "Sway RMS", "Ellipse area"
    ]

# %% [markdown]
# # Older Adults

# %%
older_adults_trial_level = pd.read_csv("../data/processed/older_adults/trial_measurements.csv")
older_adults_average_level = pd.read_csv("../data/processed/older_adults/average_measurements.csv")

older_adults_trial_level_phones = pd.read_csv("../data/processed/older_adults/phones_measurements.csv")
older_adults_average_level_phones = pd.read_csv("../data/processed/older_adults/average_phones_measurements.csv")

# %%
# Add Force Plate data
fp_trial = older_adults_trial_level[older_adults_trial_level["device"] == "Force_Plate"]
fp_avg = older_adults_average_level[older_adults_average_level["device"] == "Force_Plate"]

older_adults_trial_level_phones = pd.concat([older_adults_trial_level_phones, fp_trial])
older_adults_average_level_phones = pd.concat([older_adults_average_level_phones, fp_avg])

# %% [markdown]
# ## ZED - Force Plate

# %% [markdown]
# ### Trial-level

# %%
plot_corrleations_heatmap(older_adults_trial_level, method="spearman", exclude_metrics=exclude_metrics, row_order=row_order)

# %%
plot_state_difference_in_correlations(older_adults_trial_level, method="spearman", exclude_metrics=exclude_metrics, row_order=row_order)

# %% [markdown]
# ### Average-level

# %%
plot_corrleations_heatmap(older_adults_average_level, method="spearman", exclude_metrics=exclude_metrics, row_order=row_order)

# %%
plot_state_difference_in_correlations(older_adults_average_level, method="spearman", exclude_metrics=exclude_metrics, row_order=row_order)

# %%
plot_correlation_change_bars(older_adults_trial_level, older_adults_average_level, method="spearman", exclude_metrics=exclude_metrics, row_order=row_order)

# %% [markdown]
# ## Front phone - Force Plate

# %% [markdown]
# ### Trial-level

# %%
plot_corrleations_heatmap(older_adults_trial_level_phones, device="front", method="spearman", exclude_metrics=exclude_metrics, row_order=row_order)

# %% [markdown]
# ### Average-level

# %%
plot_corrleations_heatmap(older_adults_average_level_phones, device="front", method="spearman", exclude_metrics=exclude_metrics, row_order=row_order)

# %% [markdown]
# ## Back phone - Force Plate

# %% [markdown]
# ### Trial-level

# %%
plot_corrleations_heatmap(older_adults_trial_level_phones, device="back", method="spearman", exclude_metrics=exclude_metrics, row_order=row_order)

# %% [markdown]
# ### Average-level

# %%
plot_corrleations_heatmap(older_adults_average_level_phones, device="back", method="spearman", exclude_metrics=exclude_metrics, row_order=row_order)

# %% [markdown]
# # Students

# %%
students_trial_level = pd.read_csv("../data/processed/students/measurements.csv")
students_average_level = pd.read_csv("../data/processed/students/average_measurements.csv")

students_trial_level_phones = pd.read_csv("../data/processed/students/phones_measurements.csv")
students_average_level_phones = pd.read_csv("../data/processed/students/average_phones_measurements.csv")

# %%
# Add Force Plate data
fp_trial_students = students_trial_level[students_trial_level["device"] == "Force_Plate"]
fp_avg_students = students_average_level[students_average_level["device"] == "Force_Plate"]

students_trial_level_phones = pd.concat([students_trial_level_phones, fp_trial_students])
students_average_level_phones = pd.concat([students_average_level_phones, fp_avg_students])

# %% [markdown]
# ## ZED - Force Plate

# %% [markdown]
# ### Trial-level

# %%
plot_corrleations_heatmap(students_trial_level, method="spearman", exclude_metrics=exclude_metrics, row_order=row_order)

# %%
plot_state_difference_in_correlations(students_trial_level, method="spearman", exclude_metrics=exclude_metrics, row_order=row_order)

# %% [markdown]
# ### Average-level

# %%
plot_corrleations_heatmap(students_average_level, method="spearman", exclude_metrics=exclude_metrics, row_order=row_order)

# %%
plot_state_difference_in_correlations(students_average_level, method="spearman", exclude_metrics=exclude_metrics, row_order=row_order)

# %%
plot_correlation_change_bars(students_trial_level, students_average_level, method="spearman", exclude_metrics=exclude_metrics, row_order=row_order)

# %% [markdown]
# ## Front phone - Force Plate

# %% [markdown]
# ### Trial-level

# %%
plot_corrleations_heatmap(students_trial_level_phones, device="front", method="spearman", exclude_metrics=exclude_metrics, row_order=row_order)

# %% [markdown]
# ### Average-level

# %%
plot_corrleations_heatmap(students_average_level_phones, device="front", method="spearman", exclude_metrics=exclude_metrics, row_order=row_order)

# %% [markdown]
# ## Back phone - Force Plate

# %% [markdown]
# ### Trial-level

# %%
plot_corrleations_heatmap(students_trial_level_phones, device="back", method="spearman", exclude_metrics=exclude_metrics, row_order=row_order)

# %% [markdown]
# ### Average-level

# %%
plot_corrleations_heatmap(students_average_level_phones, device="back", method="spearman", exclude_metrics=exclude_metrics, row_order=row_order)
