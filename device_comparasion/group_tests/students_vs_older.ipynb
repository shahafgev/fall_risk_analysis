# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), "..", ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
import pandas as pd
from src.group_significance import test_significant_differences, plot_metrics_with_significance_side_by_side

# %%
older_adults_average_level = pd.read_csv("../../data/processed/older_adults/average_measurements.csv")
students_average_level = pd.read_csv("../../data/processed/students/average_measurements.csv")

# %%
exclude_metrics = ["Range Ratio", "Path length"]
row_order = [
    "AP Range", "ML Range", "AP MAD", "ML MAD", "AP Max abs dev", 
    "ML Max abs dev", "AP RMS", "ML RMS", "Sway RMS", "Ellipse area"
    ]

# %%
df = test_significant_differences(df1=older_adults_average_level, df2=students_average_level, exclude_metrics=exclude_metrics, metric_order=row_order).round(3)
df
# Out:
#             Metric   State  P-value Force_Plate  P-value ZED_COM  \
# 0         AP Range    open                0.000            0.095
# 1         AP Range  closed                0.003            0.192
# 2         ML Range    open                0.001            0.010
# 3         ML Range  closed                0.001            0.054
# 4           AP MAD    open                0.069            0.334
# 5           AP MAD  closed                0.019            0.488
# 6           ML MAD    open                0.015            0.302
# 7           ML MAD  closed                0.039            0.125
# 8   AP Max abs dev    open                0.000            0.069
# 9   AP Max abs dev  closed                0.002            0.187
# 10  ML Max abs dev    open                0.001            0.005
# 11  ML Max abs dev  closed                0.001            0.034
# 12          AP RMS    open                0.019            0.284
# 13          AP RMS  closed                0.019            0.355
# 14          ML RMS    open                0.009            0.118
# 15          ML RMS  closed                0.019            0.089
# 16        Sway RMS    open                0.012            0.063
# 17        Sway RMS  closed                0.015            0.187
# 18    Ellipse area    open                0.006            0.090
# 19    Ellipse area  closed                0.009            0.142
#
#    Force_Plate test used ZED_COM test used
# 0           Mann-Whitney      Mann-Whitney
# 1           Mann-Whitney      Mann-Whitney
# 2           Mann-Whitney      Mann-Whitney
# 3           Mann-Whitney      Mann-Whitney
# 4           Mann-Whitney      Mann-Whitney
# 5           Mann-Whitney      Mann-Whitney
# 6           Mann-Whitney      Mann-Whitney
# 7           Mann-Whitney      Mann-Whitney
# 8           Mann-Whitney      Mann-Whitney
# 9           Mann-Whitney      Mann-Whitney
# 10          Mann-Whitney      Mann-Whitney
# 11          Mann-Whitney      Mann-Whitney
# 12          Mann-Whitney      Mann-Whitney
# 13          Mann-Whitney      Mann-Whitney
# 14          Mann-Whitney      Mann-Whitney
# 15          Mann-Whitney      Mann-Whitney
# 16          Mann-Whitney      Mann-Whitney
# 17          Mann-Whitney      Mann-Whitney
# 18          Mann-Whitney      Mann-Whitney
# 19          Mann-Whitney      Mann-Whitney
